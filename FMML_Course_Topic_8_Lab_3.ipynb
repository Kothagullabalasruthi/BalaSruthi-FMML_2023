# %% [markdown]
# <a href="https://colab.research.google.com/github/Kothagullabalasruthi/BalaSruthi-FMML_2023/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 15:51:00--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   205MB/s    in 0.3s
#
# 2024-03-30 15:51:00 (205 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22450  1607.03842v1  An important problem in sequential decision-ma...  stat
# 13230  1611.02315v2  The vast majority of theoretical results in ma...    cs
# 21675   0810.5117v1  In this report, we derive a non-negative serie...  stat
# 25859  1512.01055v1  In this paper, we study the problem of learnin...    cs
# 12061  1707.01945v1  Binary, or one-bit, representations of data ar...    cs
# ...             ...                                                ...   ...
# 22791  1706.08984v1  Learning by children and animals occurs effort...  stat
# 24166  1612.08534v1  Face recognition techniques have been develope...    cs
# 11814  1702.02686v2  Although a majority of the theoretical literat...  stat
# 5371    1306.0940v5  Most provably-efficient learning algorithms in...  stat
# 37777  1803.02998v1  We consider networked control systems consisti...    cs
#
#                                                    title  year  \
# 22450  Safe Policy Improvement by Minimizing Robust B...  2016
# 13230                       Learning from Untrusted Data  2016
# 21675  A non-negative expansion for small Jensen-Shan...  2008
# 25859  Occlusion-Aware Human Pose Estimation with Mix...  2015
# 12061            Simple Classification using Binary Data  2017
# ...                                                  ...   ...
# 22791  Unsupervised Learning via Total Correlation Ex...  2017
# 24166  Robust LSTM-Autoencoders for Face De-Occlusion...  2016
# 11814  Rate Optimal Estimation and Confidence Interva...  2017
# 5371   (More) Efficient Reinforcement Learning via Po...  2013
# 37777  DeepCAS: A Deep Reinforcement Learning Algorit...  2018
#
#                                                 keywords
# 22450  [important, sequential, uncertainty, guarantee...
# 13230  [theoretical, statistics, available, reasonabl...
# 21675  [expansion, divergence, probability, distribut...
# 25859  [estimation, compositional, prediction, estima...
# 12061  [representations, naturally, applications, app...
# ...                                                  ...
# 22791  [effortlessly, supervision, successes, automat...
# 24166  [recognition, techniques, developed, significa...
# 11814  [theoretical, literature, dimensional, statist...
# 5371   [efficient, algorithms, introduce, understood,...
# 37777  [networked, consisting, independent, subsystem...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22450    [important, sequential, uncertainty, guarantee...
# 13230    [theoretical, statistics, available, reasonabl...
# 21675    [expansion, divergence, probability, distribut...
# 25859    [estimation, compositional, prediction, estima...
# 12061    [representations, naturally, applications, app...
#                                ...
# 24876    [mathematical, processing, logarithmical, oper...
# 31817    [introduces, reinforcement, algorithm, compari...
# 286      [representation, representations, overlapping,...
# 28496    [smoothness, structure, smoothness, demonstrat...
# 23024    [screening, instances, different, screening, i...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8750 words.
# Out of those 4562 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f7385cba-2f11-42cc-ad7b-1c0c3d7e376f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7385cba-2f11-42cc-ad7b-1c0c3d7e376f")) {                    Plotly.newPlot(                        "f7385cba-2f11-42cc-ad7b-1c0c3d7e376f",                        [{"x":["formulation","empirical","approaches","inaccurate","minimizing","guaranteed","otherwise","approximate","guarantees","algorithm","important","uncertainty","seamlessly","relatively","outperform","improvement","significantly","sequential","including","assumptions","malicious","distribution","distributions","partitions","frameworks","immediate","framework","reasonably","optimization","available","similarly","estimated","estimating","arbitrary","information","fractions","significant","remaining","implications","decodable","guarantee","perturbed","phenomena","leveraged","estimation","theoretical","techniques","stochastic","statistical","statistics","reflection","adversary","extraction","considers","calculations","divergences","evaluation","numerical","expansion","consequently","probability","divergence","structures","structure","appearance","robustness","relationships","utilising","relations","experiments","geometric","inference","occlusion","prediction","recursively","compositional","performed","identifying","different","distances","propagation","determine","parameters","technique","occlusions","overlapping","introducing","illustrate","realistic","foundation","implementations","applications","appealing","naturally","representations","classification","computation","conditional","improving","accelerated","convergence","introduce","projection","posterior","selection","calculated","likelihood","achievements","instantaneous","nonlinear","similarities","continuous","respective","efficient","published","approximated","simulated","innovation","particles","addressed","generalizing","evaluated","algorithms","completely","classical","realizations","advancements","univariate","represent","improvements","evolutionary","highlight","strategies","filtering","frequently","cancellation","previously","identification","generalization","scenarios","nonstationary","formalism","automatic","progresses","annotation","experiment","expensive","dependency","representation","fulfilling","languages","syntactic","annotated","consistent","synthetic","dependent","linguistic","presented","automation","constituency","annotating","therefore","preserving","diffusion","anisotropic","multimedia","especially","sequences","technology","corrupted","technical","directions","smoothing","stationary","discontinuities","inherently","introduced","consistency","logarithmic","automatically","observations","establish","dimension","intrinsic","regression","furthermore","detection","validated","challenging","comparison","conjugacy","transformation","adaptation","meaningful","capturing","intuitive","inefficiency","multinomial","alternative","discovery"],"y":[66,149,446,9,54,39,22,91,55,810,359,75,8,62,92,155,267,74,243,67,10,205,107,10,26,10,529,12,301,315,15,64,61,76,731,5,242,26,29,2,37,8,29,8,207,156,354,128,152,51,12,10,147,38,8,5,263,69,16,33,161,23,129,341,68,102,60,2,87,603,61,222,31,208,11,23,112,86,760,31,64,74,235,232,19,25,49,63,59,24,28,397,22,51,214,481,132,106,97,15,105,312,40,27,158,35,54,3,6,65,29,114,14,411,36,10,55,4,5,41,18,138,575,39,88,2,3,4,113,126,57,22,102,62,28,1,99,112,107,115,3,26,174,2,63,90,60,43,341,4,110,54,61,80,154,84,64,185,5,3,10,153,43,15,5,12,120,105,54,22,54,44,14,31,4,18,125,52,15,183,81,54,48,39,129,153,349,28,255,147,1,49,74,47,39,29,2,5,97,62],"type":"bar"},{"x":["formulation","empirical","approaches","inaccurate","minimizing","guaranteed","otherwise","approximate","guarantees","algo ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4562,), (4562, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.82

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Privacy</span> <span style=''>Aware</span> <span style=''>Bayesian</span> <span style=''>Approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Combining</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classifier</span> <span style=''>and</span> <span style=''>Cluster</span> <span style='background-color:rgba(255, 0, 0, 0.4545454545454545);'>Ensembles</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style=''>privacy</span> <span style=''>aware</span> <span style=''>Bayesian</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>combines</span> <span style='background-color:rgba(255, 0, 0, 0.4545454545454545);'>ensembles</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>and</span> <span style=''>clusterers</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>transductive</span> <span style=''>learning</span> <span style=''>We</span> <span style=''>consider</span> <span style='background-color:rgba(0, 255, 0, 0.3068181818181817);'>scenarios</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instances</span> <span style=''>and</span> <span style=''>their</span> <span style=''>classificationclustering</span> <span style=''>results</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>across</span> <span style='background-color:rgba(0, 255, 0, 0.3137424373379429);'>different</span> <span style=''>data</span> <span style=''>sites</span> <span style=''>and</span> <span style=''>have</span> <span style=''>sharing</span> <span style='background-color:rgba(0, 255, 0, 0.49999999999999994);'>restrictions</span> <span style=''>As</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>the</span> <span style=''>privacy</span> <span style=''>aware</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>when</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instances</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>data</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>across</span> <span style='background-color:rgba(0, 255, 0, 0.3137424373379429);'>different</span> <span style=''>data</span> <span style=''>sites</span> <span style=''>is</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.5476190476190477);'>discussed</span> <span style='background-color:rgba(0, 255, 0, 0.37566137566137564);'>Experimental</span> <span style=''>results</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>can</span> <span style=''>provide</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style='background-color:rgba(0, 255, 0, 0.5675675675675675);'>accuracies</span> <span style=''>while</span> <span style=''>adhering</span> <span style=''>to</span> <span style=''>the</span> <span style=''>datamodel</span> <span style=''>sharing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Loosely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Connected</span> <span style=''>Markov</span> <span style=''>Random</span> <span style=''>Fields</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>that</span> <span style=''>we</span> <span style=''>call</span> <span style=''>loosely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>fields</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>short</span> <span style=''>paths</span> <span style=''>between</span> <span style=''>any</span> <span style=''>pair</span> <span style=''>of</span> <span style=''>nodes</span> <span style=''>is</span> <span style=''>small</span> <span style=''>and</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>test</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>The</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximization</span> <span style=''>step</span> <span style=''>in</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>ensures</span> <span style=''>that</span> <span style=''>the</span> <span style=''>true</span> <span style=''>edges</span> <span style=''>are</span> <span style=''>detected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correctly</span> <span style=''>even</span> <span style=''>when</span> <span style=''>there</span> <span style=''>are</span> <span style=''>short</span> <span style=''>cycles</span> <span style=''>in</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>The</span> <span style=''>number</span> <span style=''>of</span> <span style=''>samples</span> <span style=''>required</span> <span style=''>by</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>Clog</span> <span style=''>p</span> <span style=''>where</span> <span style=''>p</span> <span style=''>is</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>and</span> <span style=''>the</span> <span style=''>constant</span> <span style=''>C</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>previously</span> <span style=''>studied</span> <span style=''>models</span> <span style=''>are</span> <span style=''>examples</span> <span style=''>of</span> <span style=''>loosely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>Markov</span> <span style=''>random</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Kernels</span> <span style=''>for</span> <span style=''>Global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constraints</span> <br/><br/><span style=''>Bessiere</span> <span style=''>et</span> <span style=''>al</span> <span style=''>(AAAI08)</span> <span style=''>showed</span> <span style=''>that</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.34210526315789475);'>intractable</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagated</span> <span style=''>when</span> <span style=''>certain</span> <span style=''>natural</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>are</span> <span style=''>small</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>the</span> <span style=''>complete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraint</span> <span style=''>is</span> <span style=''>fixed</span> <span style='background-color:rgba(255, 0, 0, 0.3312883435582823);'>parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style=''>in</span> <span style=''>k</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>holes</span> <span style=''>in</span> <span style=''>domains</span> <span style=''>whenever</span> <span style=''>bound</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>can</span> <span style=''>be</span> <span style=''>enforced</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style=''>this</span> <span style=''>applies</span> <span style=''>to</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>AtMost</span> <span style=''>NValue</span> <span style=''>and</span> <span style=''>Extended</span> <span style=''>Global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Cardinality</span> <span style=''>(EGC)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>this</span> <span style=''>line</span> <span style=''>of</span> <span style=''>research</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>concept</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reduction</span> <span style=''>to</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>kernel</span> <span style=''>a</span> <span style=''>key</span> <span style=''>concept</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameterized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>to</span> <span style=''>the</span> <span style=''>field</span> <span style=''>of</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>problem</span> <span style=''>for</span> <span style=''>AtMost</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Hypergraph</span> <span style=''>and</span> <span style=''>protein</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>with</span> <span style=''>gene</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expression</span> <span style=''>data</span> <br/><br/><span style=''>Most</span> <span style=''>network</span> <span style=''>based</span> <span style=''>protein</span> <span style=''>(or</span> <span style=''>gene)</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style=''>labels</span> <span style=''>of</span> <span style=''>two</span> <span style=''>adjacent</span> <span style=''>proteins</span> <span style=''>in</span> <span style=''>the</span> <span style=''>network</span> <span style=''>are</span> <span style=''>likely</span> <span style=''>to</span> <span style=''>be</span> <span style=''>the</span> <span style=''>same</span> <span style=''>However</span> <span style=''>assuming</span> <span style=''>the</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>proteins</span> <span style=''>or</span> <span style=''>genes</span> <span style=''>is</span> <span style=''>not</span> <span style=''>complete</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>a</span> <span style=''>group</span> <span style=''>of</span> <span style=''>genes</span> <span style=''>that</span> <span style=''>show</span> <span style=''>very</span> <span style=''>similar</span> <span style=''>patterns</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expression</span> <span style=''>and</span> <span style=''>tend</span> <span style=''>to</span> <span style=''>have</span> <span style=''>similar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>(ie</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>modules)</span> <span style=''>is</span> <span style=''>missed</span> <span style=''>The</span> <span style=''>natural</span> <span style=''>way</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overcoming</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>loss</span> <span style=''>of</span> <span style=''>the</span> <span style=''>above</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>the</span> <span style=''>gene</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expression</span> <span style=''>data</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypergraph</span> <span style=''>Thus</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>the</span> <span style=''>three</span> <span style=''>un</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalized</span> <span style=''>random</span> <span style=''>walk</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypergraph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Laplacian</span> <span style=''> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08714440043212099)
# 	evaluation (0.094706517824991)
# 	experimental (0.14043932301044293)
# 	segmentation (0.06769895570759812)
# 	processing (0.11235145840835434)
# 	detection (0.12567518905293482)
# 	different (0.27367662945624777)
# 	convolutional (0.12315448325531149)
# 	information (0.2632337054375225)
# 	recognition (0.14476053294922578)
#
# Some Statistics words are:
# 	stochastic (0.12951062778052397)
# 	variables (0.13445378151260504)
# 	theoretical (0.1463173504695996)
# 	statistical (0.1517548195748888)
# 	algorithm (0.38952051408798816)
# 	estimation (0.17696490360850223)
# 	distribution (0.17647058823529413)
# 	inference (0.19327731092436976)
# 	dimensional (0.1828966880869995)
# 	regression (0.17894216510133465)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="423f30b5-9557-4686-b8f4-65b93723e3da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("423f30b5-9557-4686-b8f4-65b93723e3da")) {                    Plotly.newPlot(                        "423f30b5-9557-4686-b8f4-65b93723e3da",                        [{"x":["formulation","empirical","approaches","inaccurate","minimizing","guaranteed","otherwise","approximate","guarantees","algorithm","important","uncertainty","seamlessly","relatively","outperform","improvement","significantly","sequential","including","assumptions","malicious","distribution","distributions","partitions","frameworks","immediate","framework","reasonably","optimization","available","similarly","estimated","estimating","arbitrary","information","fractions","significant","remaining","implications","decodable","guarantee","perturbed","phenomena","leveraged","estimation","theoretical","techniques","stochastic","statistical","statistics","reflection","adversary","extraction","considers","calculations","divergences","evaluation","numerical","expansion","consequently","probability","divergence","structures","structure","appearance","robustness","relationships","utilising","relations","experiments","geometric","inference","occlusion","prediction","recursively","compositional","performed","identifying","different","distances","propagation","determine","parameters","technique","occlusions","overlapping","introducing","illustrate","realistic","foundation","implementations","applications","appealing","naturally","representations","classification","computation","conditional","improving","accelerated","convergence","introduce","projection","posterior","selection","calculated","likelihood","achievements","instantaneous","nonlinear","similarities","continuous","respective","efficient","published","approximated","simulated","innovation","particles","addressed","generalizing","evaluated","algorithms","completely","classical","realizations","advancements","univariate","represent","improvements","evolutionary","highlight","strategies","filtering","frequently","cancellation","previously","identification","generalization","scenarios","nonstationary","formalism","automatic","progresses","annotation","experiment","expensive","dependency","representation","fulfilling","languages","syntactic","annotated","consistent","synthetic","dependent","linguistic","presented","automation","constituency","annotating","therefore","preserving","diffusion","anisotropic","multimedia","especially","sequences","technology","corrupted","technical","directions","smoothing","stationary","discontinuities","inherently","introduced","consistency","logarithmic","automatically","observations","establish","dimension","intrinsic","regression","furthermore","detection","validated","challenging","comparison","conjugacy","transformation","adaptation","meaningful","capturing","intuitive","inefficiency","multinomial","alternative","discovery","variables","modelling","circumvent","performance","multivariate","associated","documents","application","correlated","resulting","auxiliary","formidable","correlations","additional","simplicity","sophisticated","scalability","architectures","contribute","multidimensional","dimensional","providing","leveraging","topological","functions","difficult","possibility","ensembles","simulations","diversity","multiscale","neighborhoods","specifically","dramatically","favorably","coverings","increased","understand","dimensionality","combining","stability","discriminators","conditionally","generative","unlabeled","attributes","experimental","respectively","demonstrate","supervised","independent","effectiveness","background","extending","assumption","perfectly","requiring","calibrated","i ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	linearnonlinear
# 	autocorrelation
# 	multiplayer
# 	cytometry
# 	differentiability
# 	parameterizes
# 	layerwise
# 	kontorovich
# 	encountering
# 	textitfixed
# 	ferromagnetic
# 	newsgroup
# 	geostatistical
# 	confounders
# 	ergodicity
# 	unregularized
# 	semiparametric
# 	downweighting
# 	davenport
# 	interdependence
# Some words which never appear in Statistics papers:
# 	fractions
# 	decodable
# 	reflection
# 	utilising
# 	occlusions
# 	syntactic
# 	constituency
# 	annotating
# 	skeletons
# 	terrestrial
# 	fractures
# 	sandboxing
# 	developer
# 	conference
# 	interchangeably
# 	animations
# 	benefited
# 	subtracting
# 	quaternary
# 	extractive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.092911047878263e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.775
