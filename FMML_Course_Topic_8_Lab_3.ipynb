# %% [markdown]
# <a href="https://colab.research.google.com/github/Kothagullabalasruthi/BalaSruthi-FMML_2023/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-10 11:19:08--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   313MB/s    in 0.2s
#
# 2024-04-10 11:19:09 (313 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6821   1706.04918v1  We study the problem of maximizing a monotone ...  stat
# 10640   1206.3237v1  We introduce Clique Matrices as an alternative...    cs
# 1730    1411.2674v3  We present the Bayesian Echo Chamber, a new Ba...  stat
# 17409  1711.00247v1  Virtual assistants and text chatbots have rece...    cs
# 5167    1102.3949v2  We address the sparse signal recovery problem ...  stat
# ...             ...                                                ...   ...
# 14587  cs/0308020v1  The paper reports on efforts taken to create l...    cs
# 15700  1602.04427v2  There is a wealth of information about financi...    cs
# 22242  1510.00850v3  A latent space model for a family of random gr...  stat
# 10479   1406.2721v1  Gaussian graphical models (GGM) have been wide...  stat
# 6978   1708.05789v1  We introduce a new model for building conditio...  stat
#
#                                                    title  year  \
# 6821   Robust Submodular Maximization: A Non-Uniform ...  2017
# 10640  Clique Matrices for Statistical Graph Decompos...  2012
# 1730   The Bayesian Echo Chamber: Modeling Social Inf...  2014
# 17409  Improved Text Language Identification for the ...  2017
# 5167   Sparse Signal Recovery with Temporally Correla...  2011
# ...                                                  ...   ...
# 14587  LERIL : Collaborative Effort for Creating Lexi...  2003
# 15700  Exploiting Lists of Names for Named Entity Ide...  2016
# 22242  Maximum Likelihood Latent Space Embedding of L...  2015
# 10479  Learning Latent Variable Gaussian Graphical Mo...  2014
# 6978                    Semi-supervised Conditional GANs  2017
#
#                                                 keywords
# 6821   [maximizing, submodular, cardinality, constrai...
# 10640  [introduce, alternative, representation, undir...
# 1730   [generative, interaction, evolution, discovers...
# 17409  [assistants, popularity, interactions, identif...
# 5167   [measurement, temporally, correlated, algorith...
# ...                                                  ...
# 14587  [resources, pertaining, languages, collaborati...
# 15700  [information, financial, collections, speciali...
# 22242  [probabilities, determined, positions, statist...
# 10479  [graphical, dimensional, applications, biologi...
# 6978   [introduce, conditional, generative, supervise...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6821     [maximizing, submodular, cardinality, constrai...
# 10640    [introduce, alternative, representation, undir...
# 1730     [generative, interaction, evolution, discovers...
# 17409    [assistants, popularity, interactions, identif...
# 5167     [measurement, temporally, correlated, algorith...
#                                ...
# 7262     [generative, autoregressive, recurrent, stocha...
# 27016    [multimodal, efficiency, diagnosis, multimodal...
# 23028    [processes, containing, processes, endogenous,...
# 7727     [structure, generative, autoencoders, adversar...
# 12167    [regression, beginalign, dimensional, motivate...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8883 words.
# Out of those 4541 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="78c207d0-3895-4861-aa23-ea665ec311e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78c207d0-3895-4861-aa23-ea665ec311e8")) {                    Plotly.newPlot(                        "78c207d0-3895-4861-aa23-ea665ec311e8",                        [{"x":["summarization","consisting","maximizing","cardinality","algorithm","performance","presenting","constraint","guarantee","numerically","partitions","demonstrate","partitioning","constructs","approximation","exponentially","increasing","demonstrating","optimization","subroutines","submodular","maximization","construct","influence","partitioned","considered","alternative","inference","generalisation","restricted","introduce","description","according","encourages","variational","undirected","representation","decomposable","connected","structured","constraints","decompose","decomposition","incidence","overlapping","statistical","generative","interaction","discovers","transcripts","multivariate","uncovering","capabilities","arguments","primarily","discussions","committee","evidenced","linguistic","inferring","relationships","evolution","languages","hopefully","pipelines","prediction","especially","published","multilingual","investigates","popularity","reproducible","reduction","important","classifier","assistants","processing","identification","distinguish","characters","accurately","detection","interactions","algorithms","temporally","underdetermined","extensive","significantly","interesting","theoretical","experiments","measurement","desirable","furthermore","correlations","correlated","framework","performed","resulting","mathematical","specifying","behaviour","likelihood","construction","naturally","empirically","approximate","sensitive","boltzmann","adaptively","requiring","carefully","extending","definition","infinitely","competitive","parametric","solutions","composing","comparisons","discriminative","satellite","composable","practical","graphical","clustering","measurements","abstraction","hierarchical","computational","integration","identifies","probabilistic","programming","arbitrary","techniques","introduces","illustrated","approaches","dimensionality","different","difficult","population","libraries","representative","applications","surfacing","curvilinear","structure","robustness","reasoning","industrial","exploring","impressive","reconstructed","constrained","representations","reconstructing","acquisition","multiview","intensities","reconstructions","reconstruction","dimensional","producing","particular","correlating","exceptions","increased","completing","unorganized","occlusion","controlled","understanding","relationship","massively","artificial","investigation","individual","empirical","induction","properties","investigated","consistent","constructed","specially","similarity","handwritten","classified","technique","classification","refinement","optimized","decisions","recognition","horizontal","extension","stochastic","evidences","underpins"],"y":[28,39,25,7,813,886,20,97,34,11,14,547,15,22,121,14,96,22,294,1,11,26,95,65,7,136,107,221,9,53,332,82,117,14,50,12,387,5,77,111,168,15,78,3,21,160,107,87,6,3,21,5,48,18,26,7,4,1,69,27,76,58,109,7,17,243,129,37,20,33,21,5,107,364,136,5,278,123,34,41,74,329,82,589,22,0,167,248,61,164,607,32,31,148,35,29,516,131,152,73,10,29,56,83,57,66,123,51,17,30,61,25,31,50,6,120,37,161,12,38,82,9,5,137,53,144,52,29,98,302,54,16,147,121,81,342,85,19,466,57,774,156,45,5,40,436,2,4,348,101,138,24,55,24,14,56,254,20,40,3,6,11,106,179,29,274,3,5,43,4,2,25,37,155,80,8,151,24,105,150,21,205,52,81,64,19,168,30,30,265,515,25,52,62,414,6,70,127,7,3],"type":"bar"},{"x":["summarization","consisting","maximizing","cardinality","algorithm","perf ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4541,), (4541, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8275

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Reduced</span> <span style=''>Space</span> <span style=''>and</span> <span style=''>Faster</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convergence</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Imperfect</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Information</span> <span style=''>Games</span> <span style=''>via</span> <span style=''>Regret</span> <span style=''>Based</span> <span style=''>Pruning</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.368421052631579);'>Counterfactual</span> <span style=''>Regret</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimization</span> <span style=''>(CFR)</span> <span style=''>is</span> <span style=''>the</span> <span style=''>most</span> <span style=''>popular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>zero</span> <span style=''>sum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imperfect</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>games</span> <span style=''>Regret</span> <span style=''>Based</span> <span style=''>Pruning</span> <span style=''>(RBP)</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.35042735042735046);'>improvement</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>poorly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style=''>actions</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>temporarily</span> <span style=''>pruned</span> <span style=''>thus</span> <span style=''>speeding</span> <span style=''>up</span> <span style=''>CFR</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>Total</span> <span style=''>RBP</span> <span style=''>a</span> <span style=''>new</span> <span style=''>form</span> <span style=''>of</span> <span style=''>RBP</span> <span style=''>that</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>space</span> <span style='background-color:rgba(0, 255, 0, 0.3975903614457831);'>requirements</span> <span style=''>of</span> <span style=''>CFR</span> <span style=''>as</span> <span style=''>actions</span> <span style=''>are</span> <span style=''>pruned</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>in</span> <span style=''>zero</span> <span style=''>sum</span> <span style=''>games</span> <span style=''>it</span> <span style='background-color:rgba(255, 0, 0, 0.53125);'>asymptotically</span> <span style=''>prunes</span> <span style=''>any</span> <span style=''>action</span> <span style=''>that</span> <span style=''>is</span> <span style=''>not</span> <span style=''>part</span> <span style=''>of</span> <span style=''>a</span> <span style=''>best</span> <span style=''>response</span> <span style=''>to</span> <span style=''>some</span> <span style=''>Nash</span> <span style='background-color:rgba(0, 255, 0, 0.42857142857142855);'>equilibrium</span> <span style=''>This</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>provably</span> <span style=''>faster</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>and</span> <span style=''>lower</span> <span style=''>space</span> <span style='background-color:rgba(0, 255, 0, 0.3975903614457831);'>requirements</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experiments</span> <span style=''>show</span> <span style=''>that</span> <span style=''>Total</span> <span style=''>RBP</span> <span style=''>results</span> <span style=''>in</span> <span style=''>an</span> <span style=''>order ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analytics</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>reducing</span> <span style=''>avoidable</span> <span style=''>hospital</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>readmission</span> <br/><br/><span style=''>Hospital</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>readmission</span> <span style=''>has</span> <span style=''>become</span> <span style=''>a</span> <span style=''>critical</span> <span style=''>metric</span> <span style=''>of</span> <span style=''>quality</span> <span style=''>and</span> <span style=''>cost</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>healthcare</span> <span style=''>Medicare</span> <span style=''>anticipates</span> <span style=''>that</span> <span style=''>nearly</span> <span style=''>17</span> <span style=''>billion</span> <span style=''>is</span> <span style=''>paid</span> <span style=''>out</span> <span style=''>on</span> <span style=''>the</span> <span style=''>20</span> <span style=''>of</span> <span style=''>patients</span> <span style=''>who</span> <span style=''>are</span> <span style=''>readmitted</span> <span style=''>within</span> <span style=''>30</span> <span style=''>days</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discharge</span> <span style=''>Although</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interventions</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style=''>care</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>management</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discharge</span> <span style=''>reengineering</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practiced</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sustainability</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>how</span> <span style=''>well</span> <span style=''>they</span> <span style=''>can</span> <span style=''>identify</span> <span style=''>and</span> <span style=''>target</span> <span style=''>patients</span> <span style=''>at</span> <span style=''>high</span> <span style=''>risk</span> <span style=''>of</span> <span style=''>rehospitalization</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>most</span> <span style=''>current</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>models</span> <span style=''>fail</span> <span style=''>to</span> <span style=''>reach</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acceptable</span> <span style=''>accuracy</span> <span style=''>level</span> <span style=''>none</span> <span style=''>of</span> <span style=''>them</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considers</span> <span style=''>patients</span> <span style=''>history</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>readmission</span> <span style=''>and</span> <span style=''>impacts</span> <span style=''>of</span> <span style=''>patient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attribute</span> <span style=''>changes</span> <span style=''>over</span> <span style=''>time</span> <span style=''>and</span> <span style=''>they</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Random</span> <span style=''>Feature</span> <span style=''>Maps</span> <span style=''>for</span> <span style=''>Dot</span> <span style=''>Product</span> <span style=''>Kernels</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Approximating</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>kernels</span> <span style=''>using</span> <span style=''>feature</span> <span style=''>maps</span> <span style=''>has</span> <span style=''>gained</span> <span style=''>a</span> <span style=''>lot</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>due</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>reducing</span> <span style=''>training</span> <span style=''>and</span> <span style=''>testing</span> <span style=''>times</span> <span style=''>of</span> <span style=''>SVM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>and</span> <span style=''>other</span> <span style=''>kernel</span> <span style=''>based</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>We</span> <span style=''>extend</span> <span style=''>this</span> <span style=''>line</span> <span style=''>of</span> <span style=''>work</span> <span style=''>and</span> <span style=''>present</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>distortion</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embeddings</span> <span style=''>for</span> <span style=''>dot</span> <span style=''>product</span> <span style=''>kernels</span> <span style=''>into</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Euclidean</span> <span style=''>spaces</span> <span style=''>We</span> <span style=''>base</span> <span style=''>our</span> <span style=''>results</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style=''>result</span> <span style=''>in</span> <span style=''>harmonic</span> <span style=''>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterizing</span> <span style=''>all</span> <span style=''>dot</span> <span style=''>product</span> <span style=''>kernels</span> <span style=''>and</span> <span style=''>use</span> <span style=''>it</span> <span style=''>to</span> <span style=''>define</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>randomized</span> <span style=''>feature</span> <span style=''>maps</span> <span style=''>into</span> <span style=''>explicit</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.35379061371841153);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Euclidean</span> <span style=''>spaces</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style=''>native</span> <span style=''>dot</span> <span style=''>product</span> <span style=''>provides</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>to</span> <span style=''>the</span> <span style=''>dot</span> <span style=''>product</span> <span style=''>kernel</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confidence</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>strategy</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selective</span> <span style=''>cluster</span> <span style=''>ensemble</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Diversity</span> <span style=''>and</span> <span style=''>Independency</span> <br/><br/><span style=''>This</span> <span style=''>research</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style=''>new</span> <span style=''>strategy</span> <span style=''>in</span> <span style=''>cluster</span> <span style=''>ensemble</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>by</span> <span style=''>using</span> <span style=''>Independency</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Diversity</span> <span style=''>metrics</span> <span style=''>In</span> <span style=''>recent</span> <span style=''>years</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Diversity</span> <span style=''>and</span> <span style=''>Quality</span> <span style=''>which</span> <span style=''>are</span> <span style=''>two</span> <span style=''>metrics</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>have</span> <span style=''>been</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>basic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>results</span> <span style=''>in</span> <span style=''>the</span> <span style=''>cluster</span> <span style=''>ensemble</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>Although</span> <span style=''>quality</span> <span style=''>can</span> <span style=''>improve</span> <span style=''>the</span> <span style=''>final</span> <span style=''>results</span> <span style=''>in</span> <span style=''>cluster</span> <span style=''>ensemble</span> <span style=''>it</span> <span style=''>cannot</span> <span style=''>control</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generating</span> <span style=''>basic</span> <span style=''>results</span> <span style=''>which</span> <span style=''>causes</span> <span style=''>a</span> <span style=''>gap</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>basic</span> <span style=''>results</span> <span style=''>accuracy</span> <span style=''>Instead</span> <span style=''>of</span> <span style=''>quality</span> <span style=''>this</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>Independency</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supplementary</span> <span style=''>method</span> <span style=''>to</span> <span style=''>be</span> <span style=''>used</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conjunction</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Diversity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>uses</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heuristic</sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.07909806728704366)
# 	experimental (0.13636363636363635)
# 	information (0.24838940586972083)
# 	segmentation (0.06979241231209735)
# 	evaluation (0.09949892627057981)
# 	representation (0.1385110952040086)
# 	detection (0.11775232641374374)
# 	convolutional (0.12884753042233357)
# 	different (0.2770221904080172)
# 	recognition (0.1481746599856836)
#
# Some Statistics words are:
# 	stochastic (0.13609172482552342)
# 	theoretical (0.14955134596211367)
# 	statistical (0.14905284147557327)
# 	distributions (0.13010967098703888)
# 	algorithm (0.3948155533399801)
# 	estimation (0.17547357926221335)
# 	inference (0.19990029910269191)
# 	dimensional (0.18693918245264207)
# 	distribution (0.18743768693918245)
# 	regression (0.18295114656031905)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0e9edf76-e328-4561-812e-72d355c5f0a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e9edf76-e328-4561-812e-72d355c5f0a1")) {                    Plotly.newPlot(                        "0e9edf76-e328-4561-812e-72d355c5f0a1",                        [{"x":["summarization","consisting","maximizing","cardinality","algorithm","performance","presenting","constraint","guarantee","numerically","partitions","demonstrate","partitioning","constructs","approximation","exponentially","increasing","demonstrating","optimization","subroutines","submodular","maximization","construct","influence","partitioned","considered","alternative","inference","generalisation","restricted","introduce","description","according","encourages","variational","undirected","representation","decomposable","connected","structured","constraints","decompose","decomposition","incidence","overlapping","statistical","generative","interaction","discovers","transcripts","multivariate","uncovering","capabilities","arguments","primarily","discussions","committee","evidenced","linguistic","inferring","relationships","evolution","languages","hopefully","pipelines","prediction","especially","published","multilingual","investigates","popularity","reproducible","reduction","important","classifier","assistants","processing","identification","distinguish","characters","accurately","detection","interactions","algorithms","temporally","underdetermined","extensive","significantly","interesting","theoretical","experiments","measurement","desirable","furthermore","correlations","correlated","framework","performed","resulting","mathematical","specifying","behaviour","likelihood","construction","naturally","empirically","approximate","sensitive","boltzmann","adaptively","requiring","carefully","extending","definition","infinitely","competitive","parametric","solutions","composing","comparisons","discriminative","satellite","composable","practical","graphical","clustering","measurements","abstraction","hierarchical","computational","integration","identifies","probabilistic","programming","arbitrary","techniques","introduces","illustrated","approaches","dimensionality","different","difficult","population","libraries","representative","applications","surfacing","curvilinear","structure","robustness","reasoning","industrial","exploring","impressive","reconstructed","constrained","representations","reconstructing","acquisition","multiview","intensities","reconstructions","reconstruction","dimensional","producing","particular","correlating","exceptions","increased","completing","unorganized","occlusion","controlled","understanding","relationship","massively","artificial","investigation","individual","empirical","induction","properties","investigated","consistent","constructed","specially","similarity","handwritten","classified","technique","classification","refinement","optimized","decisions","recognition","horizontal","extension","stochastic","evidences","underpins","distributed","generalization","structures","constraining","formulation","dimension","objective","embedding","motivated","regardless","outperforms","optimizing","maximally","essential","surrounding","discusses","comprehend","dedicated","comprehensive","transform","information","achieving","algorithmic","compactly","derivatives","intensive","fundamental","typically","computationally","invariant","extraction","technology","potential","opportunities","performances","specifically","structural","evaluation","available","generator","expensive","experimentation","simulations","conducted","development","simulation","overfitting","parameters","unsupervised","scenarios","distributions","workflows","developed","supervised","usabilit ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	underdetermined
# 	generalises
# 	preventive
# 	functoriality
# 	kleinberg
# 	stratifying
# 	retention
# 	infectious
# 	nonconjugate
# 	discriminatory
# 	syndromes
# 	abundances
# 	disclosed
# 	perceptrons
# 	tightness
# 	exposition
# 	therapies
# 	ancillary
# 	covariances
# 	unprocessed
# Some words which never appear in Statistics papers:
# 	assistants
# 	surfacing
# 	unorganized
# 	underpins
# 	comprehend
# 	formalisms
# 	bilateral
# 	hypothetically
# 	photometric
# 	integrity
# 	dependant
# 	norwegian
# 	delimited
# 	processors
# 	threatening
# 	affordable
# 	marketplace
# 	justifications
# 	reasoners
# 	rewriting

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.078722945722115e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7866666666666666
